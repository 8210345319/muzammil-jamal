# %%
#under arithmetic error class zerodivisionerror,floatingpointerror,overflowerror,value error etc included.

# %%
variable=5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 variable=5/0
#
# ZeroDivisionError: division by zero

# %%
try:
    variable=5/0
    print(variable)
except ArithmeticError:
    print("this is an arithmetic error")
# Out:
# this is an arithmetic error

# %%
a=5
for i in range(1,1000):
        a=a**i
        print(a)
# Out:
# 5
# 25
# 15625
# 59604644775390625
# 752316384526264005099991383822237233803945956334136013765601092018187046051025390625
# ...
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       2 for i in range(1,1000):
#       3         a=a**i
# ----> 4         print(a)
#
# ValueError: Exceeds the limit (4300 digits) for integer string conversion; use sys.set_int_max_str_digits() to increase the limit

# %%
a=5
try:
    for i in range(1,1000):
        a=a**i
        print(a)
except ValueError as e:
            print("value error happened")
            print(f"{e}, {e.__class__}")
# Out:
# 5
# 25
# 15625
# 59604644775390625
# 752316384526264005099991383822237233803945956334136013765601092018187046051025390625
# ...
# ...
# value error happened
# Exceeds the limit (4300 digits) for integer string conversion; use sys.set_int_max_str_digits() to increase the limit, <class 'ValueError'>
